# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Load Dataset

# %%
# path
shared_articles = 'archive/shared_articles.csv'
users_interactions = 'archive/users_interactions.csv'

# %%
# load dataset
shared_articles = pd.read_csv(shared_articles)
users_interactions = pd.read_csv(users_interactions)

# %% [markdown]
# # Shared Articles Dataset

# %%
shared_articles = shared_articles[shared_articles['eventType']=='CONTENT SHARED']
shared_articles
# Out:
#        timestamp       eventType            contentId       authorPersonId  \
# 1     1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 2     1459194146  CONTENT SHARED -7292285110016212249  4340306774493623681
# 3     1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
# 4     1459194497  CONTENT SHARED  2448026894306402386  4340306774493623681
# 5     1459194522  CONTENT SHARED -2826566343807132236  4340306774493623681
# ...          ...             ...                  ...                  ...
# 3117  1487946604  CONTENT SHARED  9213260650272029784  3609194402293569455
# 3118  1487947067  CONTENT SHARED -3295913657316686039  6960073744377754728
# 3119  1488223224  CONTENT SHARED  3618271604906293310  1908339160857512799
# 3120  1488300719  CONTENT SHARED  6607431762270322325 -1393866732742189886
# 3121  1488307871  CONTENT SHARED  4109618890343020064  3891637997717104548
#
#           authorSessionId                                    authorUserAgent  \
# 1     8940341205206233829                                                NaN
# 2     8940341205206233829                                                NaN
# 3    -1457532940883382585                                                NaN
# 4     8940341205206233829                                                NaN
# 5     8940341205206233829                                                NaN
# ...                   ...                                                ...
# 3117  7144190892417579456  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 3118 -8193630595542572738  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 3119  -183341653743161643  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0...
# 3120  2367029511384577082  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 3121 -7416795577834806518  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#      authorRegion authorCountry contentType  \
# 1             NaN           NaN        HTML
# 2             NaN           NaN        HTML
# 3             NaN           NaN        HTML
# 4             NaN           NaN        HTML
# 5             NaN           NaN        HTML
# ...           ...           ...         ...
# 3117           SP            BR        HTML
# 3118           GA            US        HTML
# 3119           SP            BR        HTML
# 3120           MG            BR        HTML
# 3121           SP            BR        HTML
#
#                                                     url  \
# 1     http://www.nytimes.com/2016/03/28/business/dea...
# 2     http://cointelegraph.com/news/bitcoin-future-w...
# 3     https://cloudplatform.googleblog.com/2016/03/G...
# 4     https://bitcoinmagazine.com/articles/ibm-wants...
# 5     http://www.coindesk.com/ieee-blockchain-oxford...
# ...                                                 ...
# 3117  https://startupi.com.br/2017/02/liga-ventures-...
# 3118  https://thenextweb.com/apps/2017/02/14/amazon-...
# 3119                        https://code.org/about/2016
# 3120  https://www.bloomberg.com/news/articles/2017-0...
# 3121  https://www.acquia.com/blog/partner/2017-acqui...
#
#                                                   title  \
# 1     Ethereum, a Virtual Currency, Enables Transact...
# 2     Bitcoin Future: When GBPcoin of Branson Wins O...
# 3                          Google Data Center 360° Tour
# 4     IBM Wants to "Evolve the Internet" With Blockc...
# 5     IEEE to Talk Blockchain at Cloud Computing Oxf...
# ...                                                 ...
# 3117  Conheça a Liga IoT, plataforma de inovação abe...
# 3118  Amazon takes on Skype and GoToMeeting with its...
# 3119                        Code.org 2016 Annual Report
# 3120  JPMorgan Software Does in Seconds What Took La...
# 3121               The 2017 Acquia Partners of the Year
#
#                                                    text lang
# 1     All of this work is still very early. The firs...   en
# 2     The alarm clock wakes me at 8:00 with stream o...   en
# 3     We're excited to share the Google Data Center ...   en
# 4     The Aite Group projects the blockchain market ...   en
# 5     One of the largest and oldest organizations fo...   en
# ...                                                 ...  ...
# 3117  A Liga Ventures, aceleradora de startups espec...   pt
# 3118  Amazon has launched Chime, a video conferencin...   en
# 3119  February 9, 2017 - We begin each year with a l...   en
# 3120  At JPMorgan Chase & Co., a learning machine is...   en
# 3121  The Acquia Partner Awards Program is comprised...   en
#
# [3047 rows x 13 columns]

# %% [markdown]
# # Users Interactions Dataset

# %%
users_interactions
# Out:
#         timestamp eventType            contentId             personId  \
# 0      1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1      1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2      1465416190      VIEW   310515487419366995 -1130272294246983140
# 3      1465413895    FOLLOW   310515487419366995   344280948527967603
# 4      1465412290      VIEW -7820640624231356730  -445337111692715325
# ...           ...       ...                  ...                  ...
# 72307  1485190425      LIKE -6590819806697898649 -9016528795238256703
# 72308  1485190425      VIEW -5813211845057621660   102305705598210278
# 72309  1485190072      VIEW -1999468346928419252 -9196668942822132778
# 72310  1485190434      VIEW -6590819806697898649 -9016528795238256703
# 72311  1485187988      VIEW  5669290109546991426  5713241217519616260
#
#                  sessionId                                          userAgent  \
# 0      1264196770339959068                                                NaN
# 1      3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2      2631864456530402479                                                NaN
# 3     -3167637573980064150                                                NaN
# 4      5611481178424124714                                                NaN
# ...                    ...                                                ...
# 72307  8614469745607949425  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 72308  5527770709392883642  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 72309 -8300596454915870873  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 72310  8614469745607949425  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 72311  6704552481483665372  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
#
#       userRegion userCountry
# 0            NaN         NaN
# 1             NY          US
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 72307         MG          BR
# 72308         SP          BR
# 72309         SP          BR
# 72310         MG          BR
# 72311         MG          BR
#
# [72312 rows x 8 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Shared Articles Dataset

# %%
shared_articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3047 entries, 1 to 3121
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        3047 non-null   int64
#  1   eventType        3047 non-null   object
#  2   contentId        3047 non-null   int64
#  3   authorPersonId   3047 non-null   int64
#  4   authorSessionId  3047 non-null   int64
#  5   authorUserAgent  669 non-null    object
#  6   authorRegion     669 non-null    object
#  7   authorCountry    669 non-null    object
#  8   contentType      3047 non-null   object
#  9   url              3047 non-null   object
#  10  title            3047 non-null   object
#  11  text             3047 non-null   object
#  12  lang             3047 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 333.3+ KB

# %% [markdown]
# Terdapat missing value pada kolom authorUserAgent, authorRegion, dan authorCountry.

# %%
shared_articles.describe(include='all')
# Out:
#            timestamp       eventType     contentId  authorPersonId  \
# count   3.047000e+03            3047  3.047000e+03    3.047000e+03
# unique           NaN               1           NaN             NaN
# top              NaN  CONTENT SHARED           NaN             NaN
# freq             NaN            3047           NaN             NaN
# mean    1.468865e+09             NaN  1.969568e+16    4.198685e+17
# std     7.573604e+06             NaN  5.376353e+18    4.390382e+18
# min     1.459194e+09             NaN -9.222795e+18   -9.120686e+18
# 25%     1.462401e+09             NaN -4.673420e+18   -1.570135e+18
# 50%     1.467176e+09             NaN  3.455744e+16   -7.092877e+17
# 75%     1.473944e+09             NaN  4.716572e+18    3.609194e+18
# max     1.488308e+09             NaN  9.222265e+18    9.210531e+18
#
#         authorSessionId                                    authorUserAgent  \
# count      3.047000e+03                                                669
# unique              NaN                                                114
# top                 NaN  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# freq                NaN                                                 70
# mean       1.694961e+17                                                NaN
# std        5.391587e+18                                                NaN
# min       -9.212055e+18                                                NaN
# 25%       -4.656768e+18                                                NaN
# 50%        3.910429e+17                                                NaN
# 75%        4.821078e+18                                                NaN
# max        9.221043e+18                                                NaN
#
#        authorRegion authorCountry contentType  \
# count           669           669        3047
# unique           19             5           3
# top              SP            BR        HTML
# freq            524           602        3027
# mean            NaN           NaN         NaN
# std             NaN           NaN         NaN
# min             NaN           NaN         NaN
# 25%             NaN           NaN         NaN
# 50%             NaN           NaN         NaN
# 75%             NaN           NaN         NaN
# max             NaN           NaN         NaN
#
#                                                       url           title  \
# count                                                3047            3047
# unique                                               3023            3003
# top     http://www.popsci.com/byzantine-science-deceiv...  Dries Buytaert
# freq                                                    4               4
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#                                                      text  lang
# count                                                3047  3047
# unique                                               3013     5
# top     Bug Type 3: Missing Specifications Description...    en
# freq                                                    4  2211
# mean                                                  NaN   NaN
# std                                                   NaN   NaN
# min                                                   NaN   NaN
# 25%                                                   NaN   NaN
# 50%                                                   NaN   NaN
# 75%                                                   NaN   NaN
# max                                                   NaN   NaN

# %%
shared_articles.isna().sum()
# Out:
# timestamp             0
# eventType             0
# contentId             0
# authorPersonId        0
# authorSessionId       0
# authorUserAgent    2378
# authorRegion       2378
# authorCountry      2378
# contentType           0
# url                   0
# title                 0
# text                  0
# lang                  0
# dtype: int64

# %%
shared_articles.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Users Interactions Dataset

# %%
users_interactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72312 entries, 0 to 72311
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    72312 non-null  int64
#  1   eventType    72312 non-null  object
#  2   contentId    72312 non-null  int64
#  3   personId     72312 non-null  int64
#  4   sessionId    72312 non-null  int64
#  5   userAgent    56918 non-null  object
#  6   userRegion   56907 non-null  object
#  7   userCountry  56918 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 4.4+ MB

# %%
users_interactions.describe(include='all')
# Out:
#            timestamp eventType     contentId      personId     sessionId  \
# count   7.231200e+04     72312  7.231200e+04  7.231200e+04  7.231200e+04
# unique           NaN         5           NaN           NaN           NaN
# top              NaN      VIEW           NaN           NaN           NaN
# freq             NaN     61086           NaN           NaN           NaN
# mean    1.470103e+09       NaN -3.033423e+16  1.252026e+16  3.421273e+16
# std     7.258130e+06       NaN  5.344755e+18  5.022333e+18  5.344355e+18
# min     1.457964e+09       NaN -9.222795e+18 -9.223122e+18 -9.222505e+18
# 25%     1.464876e+09       NaN -4.726309e+18 -3.596627e+18 -4.613476e+18
# 50%     1.468343e+09       NaN  1.893099e+16 -1.088422e+17  5.029492e+16
# 75%     1.474461e+09       NaN  4.441012e+18  3.766319e+18  4.667962e+18
# max     1.488310e+09       NaN  9.222265e+18  9.210531e+18  9.223314e+18
#
#                           userAgent userRegion userCountry
# count                         56918      56907       56918
# unique                         1090         71          23
# top     Android - Native Mobile App         SP          BR
# freq                           6761      40164       51396
# mean                            NaN        NaN         NaN
# std                             NaN        NaN         NaN
# min                             NaN        NaN         NaN
# 25%                             NaN        NaN         NaN
# 50%                             NaN        NaN         NaN
# 75%                             NaN        NaN         NaN
# max                             NaN        NaN         NaN

# %%
users_interactions.isna().sum()
# Out:
# timestamp          0
# eventType          0
# contentId          0
# personId           0
# sessionId          0
# userAgent      15394
# userRegion     15405
# userCountry    15394
# dtype: int64

# %% [markdown]
# Terdapat beberapa missing value pada kolom userAgent, userRegion, dan userCountry.

# %%
users_interactions.duplicated().sum()
# Out:
# 11

# %% [markdown]
# Terdapat data yang duplikat pada dataset user interactions.

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# Karena beberapa fitur kurang relevan dengan content-based filtering model, maka dipilih beberapa fitur yang dianggap relevan untuk dianalisa lebih lanjut.

# %% [markdown]
# ### Shared Articles Dataset

# %%
features = ['eventType','contentId','contentType','url','title','text','lang']

# %%
shared_articles.groupby('eventType').agg({
    'text':'count'
})
# Out:
#                 text
# eventType
# CONTENT SHARED  3047

# %%
shared_articles.groupby('contentId').agg({
    'text':'count'
})
# Out:
#                       text
# contentId
# -9222795471790223670     1
# -9216926795620865886     1
# -9194572880052200111     1
# -9192549002213406534     1
# -9190737901804729417     1
# ...                    ...
#  9213260650272029784     1
#  9215261273565326920     1
#  9217155070834564627     1
#  9220445660318725468     1
#  9222265156747237864     1
#
# [3047 rows x 1 columns]

# %%
shared_articles.groupby('contentType').agg({
    'text':'count'
})
# Out:
#              text
# contentType
# HTML         3027
# RICH           10
# VIDEO          10

# %%
shared_articles.groupby('title').agg({
    'text':'count'
})
# Out:
#                                                     text
# title
# ""Good Luck with That!": Teaching Machines to D...     1
# "5G está para IoT como 4G esteve para o Smartph...     1
# "Consultorias promovem a desvalorização do noss...     1
# "Disrupção não depende da tecnologia, depende d...     1
# "Eat, sleep, code, repeat" is such bullshit - S...     1
# ...                                                  ...
# ŷhat | Classifying handwritten digits using Ten...     1
# ​Google digs deeper on machine learning with ne...     1
# ​Google's AI software is moving into your iPhone       1
# ​Kubernetes 1.4: One DevOps tool to rule all th...     1
# ​Microsoft and Canonical partner to bring Ubunt...     1
#
# [3003 rows x 1 columns]

# %%
shared_articles.groupby('lang').agg({
    'text':'count'
})
# Out:
#       text
# lang
# en    2211
# es       2
# ja       2
# la       3
# pt     829

# %% [markdown]
# Berdasarkan data, dapat dilihat bahwa pada kolom lang artikel dengan bahasa 'es', 'ja', dan 'la' memiliki jumlah yang sangat sedikit.

# %% [markdown]
# ### Users Interactions Dataset

# %%
df_features = ['eventType','contentId']

# %%
users_interactions.groupby('eventType').agg({
    'timestamp':'count'
})
# Out:
#                  timestamp
# eventType
# BOOKMARK              2463
# COMMENT CREATED       1611
# FOLLOW                1407
# LIKE                  5745
# VIEW                 61086

# %% [markdown]
# Berdasarkan interaksi pada kolom eventType, interaksi - interaksi tersebut dapat dikaitkan dengan bobot. Sebagai contoh, artikel yang diikuti oleh pengguna menunjukkan ketertarikan dibandingkan dengan artikel yang hanya dilihat oleh pengguna.

# %%
users_interactions.groupby('contentId').agg({
    'timestamp':'count'
})
# Out:
#                       timestamp
# contentId
# -9222795471790223670         26
# -9216926795620865886         21
# -9194572880052200111         29
# -9192549002213406534         56
# -9190737901804729417          9
# ...                         ...
#  9213260650272029784         11
#  9215261273565326920         30
#  9217155070834564627         16
#  9220445660318725468         52
#  9222265156747237864          5
#
# [2987 rows x 1 columns]

# %% [markdown]
# # Data Preprocessing

# %%
# membuat dataset baru berdasarkan fitur - fitur tertentu dari dataset shared articles dan users interactions

df_sa = shared_articles[['contentId','title','text','lang']]
df_ui = users_interactions[['contentId','eventType','personId']]

# %% [markdown]
# ### Menghapus data duplikat

# %%
df_sa = df_sa.drop_duplicates()
df_ui = df_ui.drop_duplicates()

# %%
df_sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3047 entries, 1 to 3121
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   contentId  3047 non-null   int64
#  1   title      3047 non-null   object
#  2   text       3047 non-null   object
#  3   lang       3047 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 119.0+ KB

# %%
df_ui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50938 entries, 0 to 72311
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   contentId  50938 non-null  int64
#  1   eventType  50938 non-null  object
#  2   personId   50938 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Mengubah eventType pada dataset users interactions

# %%
event_type_strength = {
   'VIEW': 1.0,
   'LIKE': 2.0, 
   'BOOKMARK': 3.0, 
   'FOLLOW': 4.0,
   'COMMENT CREATED': 5.0,  
}

df_ui['rating'] = df_ui['eventType'].apply(lambda x: event_type_strength[x])

# %%
df_ui.describe()
# Out:
#           contentId      personId        rating
# count  5.093800e+04  5.093800e+04  50938.000000
# mean  -4.172038e+16 -3.332220e+16      1.392163
# std    5.357533e+18  5.055287e+18      0.908675
# min   -9.222795e+18 -9.223122e+18      1.000000
# 25%   -4.754224e+18 -3.620818e+18      1.000000
# 50%   -1.038011e+15 -1.088422e+17      1.000000
# 75%    4.558204e+18  3.803524e+18      1.000000
# max    9.222265e+18  9.210531e+18      5.000000

# %% [markdown]
# Di Deskdrop, pengguna diizinkan untuk melihat artikel berkali-kali, dan berinteraksi dengannya dengan cara yang berbeda (mis. Suka atau komentar). Oleh karena itu, untuk memodelkan minat pengguna pada artikel tertentu, dilakukan penggabungan semua interaksi yang telah dilakukan pengguna dalam item dengan penjumlahan berbobot dari jenis interaksi.

# %%
df_ui = df_ui.groupby(['personId','contentId']).agg({
    'rating':'sum'
}).reset_index()

# %%
df_ui.shape
# Out:
# (40710, 3)

# %%
df_ui['rating'].sort_values(ascending=False)
# Out:
# 4499     15.0
# 9651     15.0
# 2852     15.0
# 15155    15.0
# 40285    15.0
#          ...
# 14552     1.0
# 14551     1.0
# 14550     1.0
# 14549     1.0
# 40709     1.0
# Name: rating, Length: 40710, dtype: float64

# %% [markdown]
# ### Menggabungkan kedua dataset berdasarkan contentId

# %%
df = pd.merge(df_sa,df_ui,how='outer',on='contentId')
df
# Out:
#                  contentId                                              title  \
# 0     -4110354420726924665  Ethereum, a Virtual Currency, Enables Transact...
# 1     -7292285110016212249  Bitcoin Future: When GBPcoin of Branson Wins O...
# 2     -6151852268067518688                       Google Data Center 360° Tour
# 3     -6151852268067518688                       Google Data Center 360° Tour
# 4     -6151852268067518688                       Google Data Center 360° Tour
# ...                    ...                                                ...
# 40773 -1172724258904585136                                                NaN
# 40774 -8418620743404378592                                                NaN
# 40775 -6451309518266745024                                                NaN
# 40776 -6451309518266745024                                                NaN
# 40777  3823268327704412514                                                NaN
#
#                                                     text lang      personId  \
# 0      All of this work is still very early. The firs...   en  2.873028e+18
# 1      The alarm clock wakes me at 8:00 with stream o...   en  8.414731e+18
# 2      We're excited to share the Google Data Center ...   en -7.267770e+18
# 3      We're excited to share the Google Data Center ...   en -1.443637e+18
# 4      We're excited to share the Google Data Center ...   en -1.032019e+18
# ...                                                  ...  ...           ...
# 40773                                                NaN  NaN -1.443637e+18
# 40774                                                NaN  NaN -2.050699e+18
# 40775                                                NaN  NaN -1.578288e+18
# 40776                                                NaN  NaN  4.340307e+18
# 40777                                                NaN  NaN  6.003902e+18
#
#        rating
# 0         1.0
# 1         1.0
# 2         3.0
# 3         1.0
# 4         3.0
# ...       ...
# 40773     1.0
# 40774     1.0
# 40775     1.0
# 40776     1.0
# 40777     1.0
#
# [40778 rows x 6 columns]

# %% [markdown]
# # Content-based filtering

# %% [markdown]
# Untuk kasus model content-based filtering, akan digunakan artikel dengan bahasa 'en'.

# %%
df.groupby('lang').count()
# Out:
#       contentId  title   text  personId  rating
# lang
# en        26255  26255  26255     26193   26193
# es            6      6      6         6       6
# ja           23     23     23        23      23
# la           26     26     26        26      26
# pt        14440  14440  14440     14434   14434

# %%
df = df[df['lang']=='en']

# %%
df
# Out:
#                  contentId                                              title  \
# 0     -4110354420726924665  Ethereum, a Virtual Currency, Enables Transact...
# 1     -7292285110016212249  Bitcoin Future: When GBPcoin of Branson Wins O...
# 2     -6151852268067518688                       Google Data Center 360° Tour
# 3     -6151852268067518688                       Google Data Center 360° Tour
# 4     -6151852268067518688                       Google Data Center 360° Tour
# ...                    ...                                                ...
# 40745 -3295913657316686039  Amazon takes on Skype and GoToMeeting with its...
# 40746  3618271604906293310                        Code.org 2016 Annual Report
# 40747  6607431762270322325  JPMorgan Software Does in Seconds What Took La...
# 40748  4109618890343020064               The 2017 Acquia Partners of the Year
# 40749  4109618890343020064               The 2017 Acquia Partners of the Year
#
#                                                     text lang      personId  \
# 0      All of this work is still very early. The firs...   en  2.873028e+18
# 1      The alarm clock wakes me at 8:00 with stream o...   en  8.414731e+18
# 2      We're excited to share the Google Data Center ...   en -7.267770e+18
# 3      We're excited to share the Google Data Center ...   en -1.443637e+18
# 4      We're excited to share the Google Data Center ...   en -1.032019e+18
# ...                                                  ...  ...           ...
# 40745  Amazon has launched Chime, a video conferencin...   en  6.960074e+18
# 40746  February 9, 2017 - We begin each year with a l...   en  1.908339e+18
# 40747  At JPMorgan Chase & Co., a learning machine is...   en -1.393867e+18
# 40748  The Acquia Partner Awards Program is comprised...   en -3.954277e+18
# 40749  The Acquia Partner Awards Program is comprised...   en  3.891638e+18
#
#        rating
# 0         1.0
# 1         1.0
# 2         3.0
# 3         1.0
# 4         3.0
# ...       ...
# 40745     1.0
# 40746     1.0
# 40747     1.0
# 40748     1.0
# 40749    10.0
#
# [26255 rows x 6 columns]

# %% [markdown]
# ### Menjumlahkan seluruh rating user terhadap suatu konten untuk evaluasi

# %%
df = df.groupby(['title']).agg({
    'text':'first',
    'rating':'sum'
}).reset_index()

# %%
df.describe(include='all')
# Out:
#                                                     title  \
# count                                                2173
# unique                                               2173
# top     ""Good Luck with That!": Teaching Machines to ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      text       rating
# count                                                2173  2173.000000
# unique                                               2169          NaN
# top     Create a FREE account to: Get eight free artic...          NaN
# freq                                                    3          NaN
# mean                                                  NaN    20.936954
# std                                                   NaN    27.672166
# min                                                   NaN     0.000000
# 25%                                                   NaN     5.000000
# 50%                                                   NaN    12.000000
# 75%                                                   NaN    27.000000
# max                                                   NaN   462.000000

# %% [markdown]
# ### Modeling

# %%
# list stopwords dalam bahasa Inggris
stopwords_list = stopwords.words('english') 

vectorizer = TfidfVectorizer(analyzer='word',
                     ngram_range=(1, 2),
                     min_df=0.003,
                     max_df=0.5,
                     max_features=5000,
                     stop_words=stopwords_list)

# %%
tfidf_matrix = vectorizer.fit_transform(df['title'] + " " + df['text'])

# %%
cosine_sim = cosine_similarity(tfidf_matrix)
cosine_sim_df = pd.DataFrame(cosine_sim, index=df['title'], columns=df['title'])

# %%
def get_recommendations(title, similarity_data=cosine_sim_df, items=df[['title','rating']], k=10):
  
  index = similarity_data.loc[:,title].to_numpy().argpartition(range(-1, -k, -1))
  closest = similarity_data.columns[index[-1:-(k+2):-1]]
  closest = closest.drop(title, errors='ignore')
  return pd.DataFrame(closest).merge(items).head(k)

# %% [markdown]
# ### Mendapatkan rekomendasi

# %%
get_recommendations("An operating model for company-wide agile development")
# Out:
#                                                title  rating
# 0                                    Embracing Agile   188.0
# 1  Agile is Dead, Long Live Continuous Delivery -...    24.0
# 2                                12 Agile principles     1.0
# 3                   Scrum Community - Scrum Alliance    64.0
# 4                                      Big IT Rising    50.0
# 5  Organizing for digital acceleration: Making a ...    28.0
# 6  How enterprise architects can help ensure succ...    57.0
# 7  The new tech talent you need to succeed in dig...    34.0
# 8                          Do you want Crappy Agile?    43.0
# 9  Five questions boards should ask about IT in a...    58.0

# %% [markdown]
# # Evaluasi

# %% [markdown]
# ### Precision@k

# %%
k=10
threshold = 21
sc = get_recommendations('An operating model for company-wide agile development')
ratings = sc['rating'].values
sum(ratings>threshold)/k
# Out:
# 0.9
